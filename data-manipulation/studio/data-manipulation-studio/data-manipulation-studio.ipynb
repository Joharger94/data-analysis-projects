# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit our California farmers looking for advice on growing pumpkins and the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt

baltimore = pd.read_csv(r"C:\Users\johar\LaunchCode\data-analysis-projects\data-manipulation\studio\data-manipulation-studio\dataset\baltimore_9-24-2016_9-30-2017.csv")
boston = pd.read_csv(r"C:\Users\johar\LaunchCode\data-analysis-projects\data-manipulation\studio\data-manipulation-studio\dataset\boston_9-24-2016_9-30-2017.csv")
new_york = pd.read_csv(r"C:\Users\johar\LaunchCode\data-analysis-projects\data-manipulation\studio\data-manipulation-studio\dataset\new-york_9-24-2016_9-30-2017.csv")
philadelphia = pd.read_csv(r"C:\Users\johar\LaunchCode\data-analysis-projects\data-manipulation\studio\data-manipulation-studio\dataset\philadelphia_9-24-2016_9-30-2017.csv")

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data to related to San Francisco. Pull up your notebook from the last lesson and use your cleaning skills to clean the dataframes as necessary.

# %%
# Clean your data here!
northeast_region["Repack"] = northeast_region["Repack"].replace({"N":False})
northeast_region["Type"] = northeast_region["Type"].fillna("Conventional")
northeast_region = northeast_region.drop(['Grade', 'Environment', 'Mostly Low', 'Mostly High', 'Origin District', 'Quality', 'Storage', 'Crop', 'Appearance', 'Condition', 'Trans Mode'], axis=1)

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!
northeast_region = pd.concat([baltimore, boston, new_york, philadelphia], axis = 0)
northeast_region.head(10)
# Out:
#   Commodity Name  City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 1       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 2       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 5       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 6       PUMPKINS  BALTIMORE   NaN  36 inch bins  HOWDEN TYPE         NaN
# 7       PUMPKINS  BALTIMORE   NaN  36 inch bins  HOWDEN TYPE         NaN
# 8       PUMPKINS  BALTIMORE   NaN  36 inch bins  HOWDEN TYPE         NaN
# 9       PUMPKINS  BALTIMORE   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  04/29/2017        270       280.0  ...    NaN          NaN
# 1    NaN  05/06/2017        270       280.0  ...    NaN          NaN
# 2    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 3    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 4    NaN  11/05/2016         90       100.0  ...    NaN          NaN
# 5    NaN  11/12/2016         90       100.0  ...    NaN          NaN
# 6    NaN  09/24/2016        160       170.0  ...    NaN          NaN
# 7    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 8    NaN  10/01/2016        160       170.0  ...    NaN          NaN
# 9    NaN  10/01/2016        160       160.0  ...    NaN          NaN
#
#   Unit of Sale Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# 0          NaN     NaN       NaN        NaN      NaN  NaN       E         NaN
# 1          NaN     NaN       NaN        NaN      NaN  NaN       E         NaN
# 2          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 3          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 4          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 5          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 6          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 7          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 8          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 9          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
#
# [10 rows x 25 columns]

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of unit of sale in the Northeast region? In the last lesson, we learned that a unit of sale could be something like a bin or individually.
# 2. What is the average number of pumpkins for each variety that came into terminal markets for the year by region? Pumpkin varieties include Howden and Fairytale pumpkins.

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
pumpkin_unit = northeast_region.groupby(['Unit of Sale'])
pumpkin_mean = { 'Low Price' : ['mean'], 'High Price' : ['mean']}
pumpkin_prices = pumpkin_unit.agg(pumpkin_mean)
pumpkin_prices
# Out:
#                Low Price  High Price
#                     mean        mean
# Unit of Sale
# EACH           47.916667   59.166667
# PER BIN       185.845070  206.619718
# SHELLACKED     16.000000   17.545455

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.
pumpkin_origin = northeast_region.groupby(['Variety', 'Origin'])
pumpkin_count = { 'Variety' : ['count'] }
pumpkin_var_count = pumpkin_origin.agg(pumpkin_count)
pumpkin_var_count
# Out:
#                                        Variety
#                                          count
# Variety                  Origin
# BIG MACK TYPE            MARYLAND           17
#                          MASSACHUSETTS      23
#                          NEW JERSEY          2
#                          PENNSYLVANIA        6
#                          VIRGINIA            7
# BLUE TYPE                MASSACHUSETTS       7
# CINDERELLA               COSTA RICA          3
#                          FLORIDA             2
#                          MARYLAND            6
#                          MASSACHUSETTS      14
#                          MEXICO              5
#                          VIRGINIA            6
# FAIRYTALE                MARYLAND            9
#                          MASSACHUSETTS      21
#                          VIRGINIA            7
# HOWDEN TYPE              CANADA             54
#                          DELAWARE            5
#                          MARYLAND           20
#                          MASSACHUSETTS      48
#                          MICHIGAN           24
#                          NEW JERSEY         17
#                          NEW YORK           11
#                          OHIO                1
#                          PENNSYLVANIA       43
#                          VIRGINIA            1
# HOWDEN WHITE TYPE        MARYLAND            2
# KNUCKLE HEAD             MASSACHUSETTS       7
#                          NEW JERSEY          1
#                          PENNSYLVANIA        1
# MINIATURE                MARYLAND           18
#                          MASSACHUSETTS      28
#                          MICHIGAN            1
#                          NEW JERSEY          1
#                          NEW YORK            6
#                          OHIO               37
#                          PENNSYLVANIA        2
#                          VIRGINIA            4
# MIXED HEIRLOOM VARIETIES MARYLAND            3
#                          MICHIGAN            1
# PIE TYPE                 CANADA             12
#                          DELAWARE           13
#                          MARYLAND            4
#                          MASSACHUSETTS      49
#                          MICHIGAN           14
#                          NEW JERSEY         12
#                          NEW YORK            9
#                          OHIO               23
#                          PENNSYLVANIA       55
#                          VERMONT             6
#                          VIRGINIA            1

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
